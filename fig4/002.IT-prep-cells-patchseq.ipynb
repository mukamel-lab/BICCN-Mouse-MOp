# %%
import importlib
import sys
sys.path.insert(0, '/cndd/fangming/CEMBA/snmcseq_dev')

from __init__ import *
from __init__jupyterlab import *
import datetime
from scipy import sparse
import collections
import itertools
import re
import fbpca
import pickle
import scipy.cluster.hierarchy as sch
from sklearn.metrics import euclidean_distances
import h5py

import snmcseq_utils
importlib.reload(snmcseq_utils)
import CEMBA_run_tsne
import CEMBA_clst_utils
import SCF_utils
importlib.reload(SCF_utils)

import seaborn as sns 
import matplotlib.pyplot as plt

# %%
figure_format = '/cndd2/fangming/projects/miniatlas/results/figures/{}.pdf'

# %% [markdown]
# ### Gene annot

# %%
f = PATH_GENEBODY_ANNOTATION
df_genes = pd.read_csv(f, sep='\t')
df_genes['gid'] = df_genes['gene_id'].apply(lambda x: x.split('.')[0])
print(df_genes.shape)
df_genes.head()


df_genes_v2 = df_genes.groupby('gene_name').first()
print(df_genes_v2.shape)
df_genes_v2.head()
# Out:
# (53379, 8)
# (53278, 7)
#                             gene_id    chr      start        end strand  \
# gene_name
# 0610005C13Rik  ENSMUSG00000109644.1   chr7   45567794   45575327      -
# 0610006L08Rik  ENSMUSG00000108652.1   chr7   74818818   74853813      -
# 0610009B22Rik  ENSMUSG00000007777.9  chr11   51685386   51688874      -
# 0610009E02Rik  ENSMUSG00000086714.1   chr2   26445696   26459390      +
# 0610009L18Rik  ENSMUSG00000043644.4  chr11  120348678  120351190      +
#
#                                    gene_type                 gid
# gene_name
# 0610005C13Rik                  antisense_RNA  ENSMUSG00000109644
# 0610006L08Rik                        lincRNA  ENSMUSG00000108652
# 0610009B22Rik                 protein_coding  ENSMUSG00000007777
# 0610009E02Rik           processed_transcript  ENSMUSG00000086714
# 0610009L18Rik  bidirectional_promoter_lncRNA  ENSMUSG00000043644

# %% [markdown]
# ### Load data

# %%
f = '/cndd2/Public_Datasets/CEMBA/BICCN_minibrain_data/Patchseq/mini-atlas-meta-data.csv' 
meta = pd.read_csv(f, sep='\t', index_col='Cell')
print(meta.columns)
print(meta.shape)
meta.head()
# Out:
# Index(['Number', 'Date', 'Sample', 'Mouse', 'Mouse date of birth', 'Mouse age',
#        'Targeted layer', 'Cre', 'Number of genes detected', 'RNA family',
#        'RNA type', 'RNA type confidence', 'RNA type top-3', 'ALM/VISp top-3',
#        'Length (bp)', 'Yield (pg/µl)', 'User', 'Hold Time (min)',
#        'Soma depth (µm)', 'Soma depth (4x)', 'Cortical thickness (4x)',
#        'Cortical thickness (µm)', 'Traced', 'Exclusion reasons'],
#       dtype='object')
# (1320, 24)
#                    Number        Date    Sample        Mouse  \
# Cell
# 20171204_sample_2       1  2017-12-04  sample 2  mouse_GTOKH
# 20171204_sample_4       2  2017-12-04  sample 4  mouse_GTOKH
# 20171204_sample_5       3  2017-12-04  sample 5  mouse_GTOKH
# 20171204_sample_6       4  2017-12-04  sample 6  mouse_GTOKH
# 20171207_sample_1       5  2017-12-07  sample 1  mouse_UGZSW
#
#                   Mouse date of birth  Mouse age Targeted layer   Cre  \
# Cell
# 20171204_sample_2          2017-10-29         36              5   PV-
# 20171204_sample_4          2017-10-29         36              5   PV-
# 20171204_sample_5          2017-10-29         36              5   PV-
# 20171204_sample_6          2017-10-29         36              5   PV-
# 20171207_sample_1          2017-09-18         80              5  SST-
#
#                    Number of genes detected RNA family  ... Length (bp)  \
# Cell                                                    ...
# 20171204_sample_2                     10090         PT  ...        1955
# 20171204_sample_4                     10882         IT  ...        1887
# 20171204_sample_5                     14950         IT  ...        1869
# 20171204_sample_6                     10688         PT  ...        1999
# 20171207_sample_1                     16310         PT  ...        1884
#
#                    Yield (pg/µl)  User Hold Time (min) Soma depth (µm)  \
# Cell
# 20171204_sample_2          95.19  Fede             8.0           736.7
# 20171204_sample_4          80.22  Fede             9.0           726.2
# 20171204_sample_5         439.16  Fede             8.0           659.8
# 20171204_sample_6         211.71  Fede             8.0           571.7
# 20171207_sample_1         986.46  Fede            10.0           772.4
#
#                   Soma depth (4x) Cortical thickness (4x)  \
# Cell
# 20171204_sample_2           271.0                   535.8
# 20171204_sample_4           285.7                   545.9
# 20171204_sample_5           241.8                   530.4
# 20171204_sample_6           210.0                   501.1
# 20171207_sample_1           288.9                   477.1
#
#                    Cortical thickness (µm) Traced  Exclusion reasons
# Cell
# 20171204_sample_2                 1478.808      y                NaN
# 20171204_sample_4                 1506.684      y                NaN
# 20171204_sample_5                 1463.904      y                NaN
# 20171204_sample_6                 1383.036      y                NaN
# 20171207_sample_1                 1316.796      y                NaN
#
# [5 rows x 24 columns]

# %%
meta.columns
# Out:
# Index(['Number', 'Date', 'Sample', 'Mouse', 'Mouse date of birth', 'Mouse age',
#        'Targeted layer', 'Cre', 'Number of genes detected', 'RNA family',
#        'RNA type', 'RNA type confidence', 'RNA type top-3', 'ALM/VISp top-3',
#        'Length (bp)', 'Yield (pg/µl)', 'User', 'Hold Time (min)',
#        'Soma depth (µm)', 'Soma depth (4x)', 'Cortical thickness (4x)',
#        'Cortical thickness (µm)', 'Traced', 'Exclusion reasons'],
#       dtype='object')

# %%
meta['RNA family'].value_counts()
# Out:
# Pvalb          286
# Sst            272
# IT             253
# Vip            152
# CT             107
# Lamp5           92
# low quality     92
# PT              48
# Sncg            13
# NP               5
# Name: RNA family, dtype: int64

# %%
f = '/cndd2/Public_Datasets/CEMBA/BICCN_minibrain_data/Patchseq/Cell_Features_M1_3_latencies.csv'
df_ephys = pd.read_csv(f, sep=',')

def get_cell_name(x):
    _, _, _a, _b, _, _c, _d = x.split(' ')
    _a = _a.replace('/', '')
    _d = _d.replace('.mat', '')
    y = _a+_b+'_'+_c+'_'+_d
    return y 

df_ephys['Cell'] = df_ephys['name sample'].apply(get_cell_name)
df_ephys = df_ephys.set_index('Cell')
df_ephys = df_ephys.drop(['Unnamed: 0', 'name sample'], axis=1)



print(df_ephys.columns)
print(df_ephys.shape)
df_ephys.head()
# Out:
# Index(['AP Fano factor', 'AP amplitude (mV)', 'AP amplitude adaptation index',
#        'AP amplitude average adaptation index', 'AP coefficient of variation',
#        'AP threshold (mV)', 'AP width (ms)', 'Afterdepolarization (mV)',
#        'Afterhyperpolarization (mV)', 'Burstiness', 'ISI Fano factor',
#        'ISI adaptation index', 'ISI average adaptation index',
#        'ISI coefficient of variation', 'Input resistance (MOhm)',
#        'Latency (ms)', 'Latency 2 (ms)', 'Latency 3 (ms)', 'Max number of APs',
#        'Membrane time constant (ms)', 'Rebound (mV)', 'Rebound number of APs',
#        'Resting membrane potential (mV)', 'Rheobase (pA)', 'Sag area (mV*s)',
#        'Sag ratio', 'Sag time (s)', 'Spike frequency adaptation',
#        'Upstroke-to-downstroke ratio', 'Wildness'],
#       dtype='object')
# (1319, 30)
#                    AP Fano factor  AP amplitude (mV)  \
# Cell
# 20180918_sample_1        3.711764          75.569041
# 20180918_sample_2        2.710569          86.732939
# 20180918_sample_3        0.622750          80.275331
# 20180917_sample_4        2.795553          60.218537
# 20180917_sample_1        2.275313          83.007075
#
#                    AP amplitude adaptation index  \
# Cell
# 20180918_sample_1                       0.899183
# 20180918_sample_2                       0.763202
# 20180918_sample_3                       0.823658
# 20180917_sample_4                       0.812493
# 20180917_sample_1                       0.852533
#
#                    AP amplitude average adaptation index  \
# Cell
# 20180918_sample_1                               0.975435
# 20180918_sample_2                               0.953588
# 20180918_sample_3                               0.988873
# 20180917_sample_4                               0.993299
# 20180917_sample_1                               0.964800
#
#                    AP coefficient of variation  AP threshold (mV)  \
# Cell
# 20180918_sample_1                     0.279303         -33.322208
# 20180918_sample_2                     0.238525         -37.266683
# 20180918_sample_3                     0.107565         -39.591365
# 20180917_sample_4                     0.263439         -35.975985
# 20180917_sample_1                     0.208385         -42.020172
#
#                    AP width (ms)  Afterdepolarization (mV)  \
# Cell
# 20180918_sample_1           1.00                  0.719607
# 20180918_sample_2           0.96                  0.000000
# 20180918_sample_3           1.20                  0.000000
# 20180917_sample_4           0.76                  0.000000
# 20180917_sample_1           1.52                  0.000000
#
#                    Afterhyperpolarization (mV)  Burstiness  ...  Rebound (mV)  \
# Cell                                                        ...
# 20180918_sample_1                    -9.962909         0.0  ...      8.046417
# 20180918_sample_2                    -6.289858         0.0  ...     18.415515
# 20180918_sample_3                   -12.598868         0.0  ...      1.863559
# 20180917_sample_4                   -18.160298         0.0  ...      1.150502
# 20180917_sample_1                   -14.805026         0.0  ...      4.554884
#
#                    Rebound number of APs  Resting membrane potential (mV)  \
# Cell
# 20180918_sample_1                      0                       -56.181197
# 20180918_sample_2                      3                       -53.866559
# 20180918_sample_3                      0                       -74.727121
# 20180917_sample_4                      0                       -68.536296
# 20180917_sample_1                      2                       -51.042558
#
#                    Rheobase (pA)  Sag area (mV*s)  Sag ratio  Sag time (s)  \
# Cell
# 20180918_sample_1      60.000000        50.470672   1.161471       0.50236
# 20180918_sample_2      20.000000        48.478061   1.532719       0.52580
# 20180918_sample_3      40.000000         0.000000   1.020273       0.00000
# 20180917_sample_4     120.000000         0.000000   1.034109       0.00000
# 20180917_sample_1       2.222222        61.036692   1.244647       0.47428
#
#                    Spike frequency adaptation  Upstroke-to-downstroke ratio  \
# Cell
# 20180918_sample_1                    0.900000                      2.012710
# 20180918_sample_2                    0.583333                      2.025989
# 20180918_sample_3                    0.714286                      2.289149
# 20180917_sample_4                    0.920000                      1.465279
# 20180917_sample_1                    0.444444                      2.435780
#
#                    Wildness
# Cell
# 20180918_sample_1       0.0
# 20180918_sample_2       0.0
# 20180918_sample_3       0.0
# 20180917_sample_4       0.0
# 20180917_sample_1       0.0
#
# [5 rows x 30 columns]

# %%
f = '/cndd2/Public_Datasets/CEMBA/BICCN_minibrain_data/Patchseq/morphometrics_used.csv'
df_morph = pd.read_csv(f)
df_morph = df_morph.set_index('cell id')
print(df_morph.shape)
df_morph.head()
# Out:
# (642, 60)
#                    "apical" branch points  "apical" height  \
# cell id
# 20180306_sample_2                    22.0           347.16
# 20190418_sample_4                    19.0           250.38
# 20190926_sample_2                    39.0           691.59
# 20171207_sample_6                    29.0           884.31
# 20190321_sample_4                    17.0           578.35
#
#                    "apical" log1p number of outer bifurcations  \
# cell id
# 20180306_sample_2                                     2.197225
# 20190418_sample_4                                     1.098612
# 20190926_sample_2                                     2.302585
# 20171207_sample_6                                     2.302585
# 20190321_sample_4                                     1.609438
#
#                    "apical" mean bifurcation distance  "apical" robust height  \
# cell id
# 20180306_sample_2                            0.203558                281.1395
# 20190418_sample_4                            0.217682                208.8840
# 20190926_sample_2                            0.193919                640.6345
# 20171207_sample_6                            0.283247                820.6250
# 20190321_sample_4                            0.200430                463.8520
#
#                    "apical" robust width  "apical" std bifurcation distance  \
# cell id
# 20180306_sample_2              241.16650                           0.120283
# 20190418_sample_4              104.79750                           0.135181
# 20190926_sample_2              191.27025                           0.204268
# 20171207_sample_6              210.83500                           0.275741
# 20190321_sample_4              175.72900                           0.194094
#
#                    "apical" total length  "apical" width  EMD axon dendrite  \
# cell id
# 20180306_sample_2            2903.732225          354.69                NaN
# 20190418_sample_4            1620.061644          123.03                NaN
# 20190926_sample_2            5714.407846          317.22                NaN
# 20171207_sample_6            4536.961006          320.74                NaN
# 20190321_sample_4            2520.839709          244.03                NaN
#
#                    ...  dendrite z-bias  mean initial segment radius  \
# cell id            ...
# 20180306_sample_2  ...           170.19                          NaN
# 20190418_sample_4  ...           164.19                          NaN
# 20190926_sample_2  ...           491.44                          NaN
# 20171207_sample_6  ...           676.64                          NaN
# 20190321_sample_4  ...           119.43                          NaN
#
#                    normalized depth  soma radius  stems  stems exiting down  \
# cell id
# 20180306_sample_2          0.175714     9.080774    7.0            0.285714
# 20190418_sample_4          0.819682    11.338419    8.0            0.125000
# 20190926_sample_2          0.512602    24.403093    8.0            0.250000
# 20171207_sample_6          0.525323    10.786609   10.0            0.100000
# 20190321_sample_4          0.753896    12.177116    6.0            0.333333
#
#                    stems exiting to the sides  stems exiting up  \
# cell id
# 20180306_sample_2                    0.285714          0.428571
# 20190418_sample_4                    0.750000          0.125000
# 20190926_sample_2                    0.625000          0.125000
# 20171207_sample_6                    0.700000          0.200000
# 20190321_sample_4                    0.500000          0.166667
#
#                    normalized layer  cell class
# cell id
# 20180306_sample_2               2/3         exc
# 20190418_sample_4                 6         exc
# 20190926_sample_2                 5         exc
# 20171207_sample_6                 5         exc
# 20190321_sample_4                 6         exc
#
# [5 rows x 60 columns]

# %%
meta_all = meta.join(df_ephys).join(df_morph) 
print(meta.shape)
print(df_ephys.shape)
print(df_morph.shape)
print(meta_all.shape)
meta_all.head()
# Out:
# (1320, 24)
# (1319, 30)
# (642, 60)
# (1320, 114)
#                    Number        Date    Sample        Mouse  \
# Cell
# 20171204_sample_2       1  2017-12-04  sample 2  mouse_GTOKH
# 20171204_sample_4       2  2017-12-04  sample 4  mouse_GTOKH
# 20171204_sample_5       3  2017-12-04  sample 5  mouse_GTOKH
# 20171204_sample_6       4  2017-12-04  sample 6  mouse_GTOKH
# 20171207_sample_1       5  2017-12-07  sample 1  mouse_UGZSW
#
#                   Mouse date of birth  Mouse age Targeted layer   Cre  \
# Cell
# 20171204_sample_2          2017-10-29         36              5   PV-
# 20171204_sample_4          2017-10-29         36              5   PV-
# 20171204_sample_5          2017-10-29         36              5   PV-
# 20171204_sample_6          2017-10-29         36              5   PV-
# 20171207_sample_1          2017-09-18         80              5  SST-
#
#                    Number of genes detected RNA family  ... dendrite z-bias  \
# Cell                                                    ...
# 20171204_sample_2                     10090         PT  ...          507.48
# 20171204_sample_4                     10882         IT  ...          480.56
# 20171204_sample_5                     14950         IT  ...          464.87
# 20171204_sample_6                     10688         PT  ...          421.68
# 20171207_sample_1                     16310         PT  ...          426.30
#
#                    mean initial segment radius normalized depth soma radius  \
# Cell
# 20171204_sample_2                          NaN         0.498172   11.840955
# 20171204_sample_4                          NaN         0.481986    8.746500
# 20171204_sample_5                          NaN         0.450713   10.594785
# 20171204_sample_6                          NaN         0.413366    9.940110
# 20171207_sample_1                          NaN         0.586575   15.617527
#
#                   stems stems exiting down stems exiting to the sides  \
# Cell
# 20171204_sample_2  17.0           0.470588                   0.352941
# 20171204_sample_4   7.0           0.285714                   0.571429
# 20171204_sample_5   8.0           0.250000                   0.500000
# 20171204_sample_6   7.0           0.142857                   0.571429
# 20171207_sample_1   9.0           0.111111                   0.666667
#
#                    stems exiting up normalized layer  cell class
# Cell
# 20171204_sample_2          0.176471                5         exc
# 20171204_sample_4          0.142857                5         exc
# 20171204_sample_5          0.250000                5         exc
# 20171204_sample_6          0.285714                5         exc
# 20171207_sample_1          0.222222                5         exc
#
# [5 rows x 114 columns]

# %%
# out = '/cndd2/Public_Datasets/CEMBA/BICCN_minibrain_data/Patchseq/metadata_patch_combined_FX.tsv'
# meta_all.to_csv(out, sep='\t', header=True, index=True)

# %%
f = '/cndd2/Public_Datasets/CEMBA/BICCN_minibrain_data/Patchseq/final_patch_seq_allcells_intronexon_allreads.txt'
data = pd.read_csv(f, sep='\t', index_col=0)
print(data.shape)
data.head()
# Out:
# (43422, 1320)
#                20180327_sample_1  20180313_sample_3  20180315_sample_6  \
# gene
# 0610005C13Rik                  0                  0                  0
# 0610006L08Rik                  0                  0                  1
# 0610009B22Rik                 44                  0                109
# 0610009E02Rik                 45                  0                  1
# 0610009L18Rik                 12                 26                  0
#
#                20180315_sample_2  20180313_sample_2  20180327_sample_4  \
# gene
# 0610005C13Rik                  0                  0                  0
# 0610006L08Rik                  0                  1                  0
# 0610009B22Rik                  0                  0                  0
# 0610009E02Rik                  0                  3                  0
# 0610009L18Rik                  0                  0                  0
#
#                20180315_sample_5  20180313_sample_8  20180327_sample_3  \
# gene
# 0610005C13Rik                  0                  0                  0
# 0610006L08Rik                  0                  0                  0
# 0610009B22Rik                190                  0                  0
# 0610009E02Rik                 26                  0                  0
# 0610009L18Rik                131                  0                  0
#
#                20180327_sample_5  ...  20190318_sample_4  20190418_sample_9  \
# gene                              ...
# 0610005C13Rik                  0  ...                  0                  0
# 0610006L08Rik                  0  ...                  0                  0
# 0610009B22Rik                193  ...                  0                  0
# 0610009E02Rik                  0  ...                  0                  0
# 0610009L18Rik                  0  ...                  0                122
#
#                20190415_sample_8  20190409_sample_9  20181004_sample_1  \
# gene
# 0610005C13Rik                  0                  0                  0
# 0610006L08Rik                  0                  0                  0
# 0610009B22Rik                  0                296                  0
# 0610009E02Rik                  0                  1                  0
# 0610009L18Rik                  0                  0                  0
#
#                20180208_sample_1  20180329_sample_7  20181207_sample_6  \
# gene
# 0610005C13Rik                  0                  0                  0
# 0610006L08Rik                  0                  0                  0
# 0610009B22Rik                  0                  0                  0
# 0610009E02Rik                  0                  0                  0
# 0610009L18Rik                  0                  0                  0
#
#                20181208_sample_1  20181203_sample_10
# gene
# 0610005C13Rik                  0                   0
# 0610006L08Rik                  0                   0
# 0610009B22Rik                  0                   0
# 0610009E02Rik                  0                   0
# 0610009L18Rik                  0                   0
#
# [5 rows x 1320 columns]

# %% [markdown]
# ### Select IT cells only

# %%
meta_all = meta_all[meta_all['RNA family']=='IT']
cells = meta_all.index.values

print(meta_all['RNA type'].unique())
print(meta_all.shape)
meta_all.head()
# Out:
# ['L5 IT_2' 'L5 IT_1' 'L4/5 IT_2' 'L5 IT_3' 'L2/3 IT_3' 'L4/5 IT_1'
#  'L2/3 IT_2' 'L5 IT_4' 'L6 IT_2' 'L6 IT_1']
# (253, 114)
#                    Number        Date    Sample        Mouse  \
# Cell
# 20171204_sample_4       2  2017-12-04  sample 4  mouse_GTOKH
# 20171204_sample_5       3  2017-12-04  sample 5  mouse_GTOKH
# 20171207_sample_6       7  2017-12-07  sample 6  mouse_UGZSW
# 20171207_sample_7       8  2017-12-07  sample 7  mouse_UGZSW
# 20171219_sample_1       9  2017-12-19  sample 1  mouse_KKXUD
#
#                   Mouse date of birth  Mouse age Targeted layer   Cre  \
# Cell
# 20171204_sample_4          2017-10-29         36              5   PV-
# 20171204_sample_5          2017-10-29         36              5   PV-
# 20171207_sample_6          2017-09-18         80              5  SST-
# 20171207_sample_7          2017-09-18         80              5  SST-
# 20171219_sample_1          2017-10-19         61              5   PV-
#
#                    Number of genes detected RNA family  ... dendrite z-bias  \
# Cell                                                    ...
# 20171204_sample_4                     10882         IT  ...          480.56
# 20171204_sample_5                     14950         IT  ...          464.87
# 20171207_sample_6                     13097         IT  ...          676.64
# 20171207_sample_7                     15527         IT  ...          398.10
# 20171219_sample_1                      9006         IT  ...         -102.84
#
#                    mean initial segment radius normalized depth soma radius  \
# Cell
# 20171204_sample_4                          NaN         0.481986    8.746500
# 20171204_sample_5                          NaN         0.450713   10.594785
# 20171207_sample_6                          NaN         0.525323   10.786609
# 20171207_sample_7                          NaN         0.436059    8.090884
# 20171219_sample_1                          NaN         0.482852   11.141210
#
#                   stems stems exiting down stems exiting to the sides  \
# Cell
# 20171204_sample_4   7.0           0.285714                   0.571429
# 20171204_sample_5   8.0           0.250000                   0.500000
# 20171207_sample_6  10.0           0.100000                   0.700000
# 20171207_sample_7   6.0           0.166667                   0.666667
# 20171219_sample_1  10.0           0.100000                   0.600000
#
#                    stems exiting up normalized layer  cell class
# Cell
# 20171204_sample_4          0.142857                5         exc
# 20171204_sample_5          0.250000                5         exc
# 20171207_sample_6          0.200000                5         exc
# 20171207_sample_7          0.166667                5         exc
# 20171219_sample_1          0.300000                5         exc
#
# [5 rows x 114 columns]

# %%
data_sub = data[cells]
gid_lookup = df_genes_v2.reindex(data_sub.index.values)['gid'].dropna()
data_sub = data_sub.reindex(gid_lookup.index)
data_sub.index = gid_lookup.values

print(data_sub.shape)
data_sub.head()
# Out:
# (38757, 253)
#                     20171204_sample_4  20171204_sample_5  20171207_sample_6  \
# ENSMUSG00000109644                  0                  5                  0
# ENSMUSG00000108652                  1                 11                  1
# ENSMUSG00000007777                 68               1400                227
# ENSMUSG00000086714                  3                  3               1457
# ENSMUSG00000043644                  0                  0                  0
#
#                     20171207_sample_7  20171219_sample_1  20171219_sample_2  \
# ENSMUSG00000109644                  1                  0                  1
# ENSMUSG00000108652                  0                  0                  0
# ENSMUSG00000007777                  0                 23                 10
# ENSMUSG00000086714                  0                  0                 26
# ENSMUSG00000043644                380                  0                  0
#
#                     20171219_sample_3  20171219_sample_7  20180102_sample_2  \
# ENSMUSG00000109644                  0                  0                  4
# ENSMUSG00000108652                  0                  0                  3
# ENSMUSG00000007777                 10                 17                  1
# ENSMUSG00000086714                  0                 20                112
# ENSMUSG00000043644                  0                  0                  0
#
#                     20180102_sample_5  ...  20190927_sample_1  \
# ENSMUSG00000109644                  2  ...                  9
# ENSMUSG00000108652                  1  ...                  0
# ENSMUSG00000007777                323  ...                  0
# ENSMUSG00000086714                 65  ...                 13
# ENSMUSG00000043644                108  ...                  0
#
#                     20190927_sample_4  20191010_sample_1  20191010_sample_3  \
# ENSMUSG00000109644                  1                  4                  0
# ENSMUSG00000108652                  0                  3                  1
# ENSMUSG00000007777                  0                  0                104
# ENSMUSG00000086714                  0                  0                  0
# ENSMUSG00000043644                  3                423                 95
#
#                     20191105_sample_2  20191106_sample_3  20191108_sample_5  \
# ENSMUSG00000109644                  0                  0                  0
# ENSMUSG00000108652                  0                  0                  0
# ENSMUSG00000007777                  0                  0                  0
# ENSMUSG00000086714                  0                  0                  0
# ENSMUSG00000043644                171                  0                  0
#
#                     20191114_sample_3  20191114_sample_7  20191114_sample_8
# ENSMUSG00000109644                 32                  0                  0
# ENSMUSG00000108652                  1                  0                  1
# ENSMUSG00000007777                  0                  0                  0
# ENSMUSG00000086714                  0                  0                  0
# ENSMUSG00000043644                  0                  0                  0
#
# [5 rows x 253 columns]

# %%
gc_mat = GC_matrix(
    data_sub.index.values,
    data_sub.columns.values,
    sparse.coo_matrix(data_sub.values),
)

# %% [markdown]
# ### Save results

# %%
fgene = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_it/patchseq_raw.gene'
fcell = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_it/patchseq_raw.cell'
fdata = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_it/patchseq_raw.npz'

snmcseq_utils.save_gc_matrix(gc_mat, fgene, fcell, fdata)

# %%
fout = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_it/patchseq_metadata.tsv'
meta_all.to_csv(fout, sep='\t', header=True, index=True)

# %% [markdown]
# ### Ephys or Morph

# %%
f = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_it/patchseq_metadata.tsv'
meta = pd.read_csv(f, sep='\t')
print(meta.shape)
meta.head()
# Out:
# (253, 115)
#                 Cell  Number        Date    Sample        Mouse  \
# 0  20171204_sample_4       2  2017-12-04  sample 4  mouse_GTOKH
# 1  20171204_sample_5       3  2017-12-04  sample 5  mouse_GTOKH
# 2  20171207_sample_6       7  2017-12-07  sample 6  mouse_UGZSW
# 3  20171207_sample_7       8  2017-12-07  sample 7  mouse_UGZSW
# 4  20171219_sample_1       9  2017-12-19  sample 1  mouse_KKXUD
#
#   Mouse date of birth  Mouse age Targeted layer   Cre  \
# 0          2017-10-29         36              5   PV-
# 1          2017-10-29         36              5   PV-
# 2          2017-09-18         80              5  SST-
# 3          2017-09-18         80              5  SST-
# 4          2017-10-19         61              5   PV-
#
#    Number of genes detected  ... dendrite z-bias mean initial segment radius  \
# 0                     10882  ...          480.56                         NaN
# 1                     14950  ...          464.87                         NaN
# 2                     13097  ...          676.64                         NaN
# 3                     15527  ...          398.10                         NaN
# 4                      9006  ...         -102.84                         NaN
#
#    normalized depth soma radius stems stems exiting down  \
# 0          0.481986    8.746500   7.0           0.285714
# 1          0.450713   10.594785   8.0           0.250000
# 2          0.525323   10.786609  10.0           0.100000
# 3          0.436059    8.090884   6.0           0.166667
# 4          0.482852   11.141210  10.0           0.100000
#
#   stems exiting to the sides stems exiting up  normalized layer  cell class
# 0                   0.571429         0.142857                 5         exc
# 1                   0.500000         0.250000                 5         exc
# 2                   0.700000         0.200000                 5         exc
# 3                   0.666667         0.166667                 5         exc
# 4                   0.600000         0.300000                 5         exc
#
# [5 rows x 115 columns]

# %%
meta.columns.values
cols = meta.describe().columns.values

# %%
n = len(cols)
nx = 5
ny = int((n+nx-1)/nx)
order = np.sort(meta['RNA type'].unique()) 
print(order)

fig, axs = plt.subplots(ny, nx, figsize=(nx*4, ny*4))
axs = axs.flatten()
for i, (col, ax) in enumerate(zip(cols, axs)):
    sns.boxplot(ax=ax, y=col, x='RNA type', data=meta, color='white', order=order)
    sns.swarmplot(ax=ax, y=col, x='RNA type', data=meta, order=order)
    ax.set_xlabel('')
    if i != 0:
        ax.set_xticks([])
fig.subplots_adjust(wspace=0.5)
snmcseq_utils.savefig(fig, 'patchseq_features_it')
plt.show()
# Out:
# ['L2/3 IT_2' 'L2/3 IT_3' 'L4/5 IT_1' 'L4/5 IT_2' 'L5 IT_1' 'L5 IT_2'
#  'L5 IT_3' 'L5 IT_4' 'L6 IT_1' 'L6 IT_2']
