# %%
import sys
sys.path.insert(0, '/cndd/fangming/CEMBA/snmcseq_dev')
from __init__ import *
from __init__jupyterlab import *

# %%
config_dir = '/cndd/fangming/CEMBA/data/MOp_all/data_freeze_neurons/' 
config_f = 'config_scf_8mods_data_freeze_190917.py' 

sys.path.insert(0, config_dir)
exec("from {} import *".format(config_f.split('.')[0]))
second_round_summary_results = os.path.join(outdir, 'intg_summary-{}-2-round-clustering.tsv'.format(name))
output_summary_results = os.path.join(outdir, 'intg_summary-{}-3-round-clustering.tsv'.format(name))
print(output_summary_results)
# Out:
# /cndd/fangming/CEMBA/data/MOp_all/results/intg_summary-mop_8mods_0915_k30-3-round-clustering.tsv

# %%
df_info = pd.read_csv(output_summary_results, sep='\t')
print(df_info.shape)
df_info.head()
# Out:
# (408885, 17)
# /cndd/fangming/venvs/conda_dobro/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    sample  cluster_joint_r0.1  cluster_joint_r1  \
# 0     snmcseq_gene_2C_M_0                   1                11
# 1     snmcseq_gene_2C_M_1                   4                 1
# 2   snmcseq_gene_2C_M_100                   4                 1
# 3  snmcseq_gene_2C_M_1000                   4                 1
# 4  snmcseq_gene_2C_M_1001                   4                 1
#
#    cluster_joint_r2  cluster_joint_r4  tsne_x_joint  tsne_y_joint  \
# 0                10                23      0.471629     -3.134735
# 1                 8                 4     -2.414973    -12.098081
# 2                 8                49     -1.446751    -12.051894
# ...

# %% [markdown]
# ### mC level

# %%
# df_info = df_info[df_info['modality']=='snatac_gene']
# df_info['C1'] = df_info['sample'].apply(lambda x: x[len('snatac_gene_'): len('snatac_gene_CEMBA171206_3C')])
# df_info['C2'] = df_info['sample'].apply(lambda x: x[len('snatac_gene_CEMBA171206_3C_'):])
# df_info = df_info[['C1', 'C2', 'cluster_round_3']].rename(columns={'C1': 'sample', 
#                                                                      'C2': 'barcode', 
#                                                                     })

# df_info.to_csv('/cndd/fangming/for_yang/atac_mop_clusters.tsv', sep='\t', na_rep='NA', header=True, index=False)

# %%
# df_info = df_info.loc[df_info['modality']=='snmcseq_gene', ['sample', 'cluster_round_3']]

# # df_info['C1'] = df_info['sample'].apply(lambda x: x[len('snatac_gene_'): len('snatac_gene_CEMBA171206_3C')])
# # df_info['C2'] = df_info['sample'].apply(lambda x: x[len('snatac_gene_CEMBA171206_3C_'):])
# # df_info = df_info[['C1', 'C2', 'cluster_round_3']].rename(columns={'C1': 'sample', 
# #                                                                      'C2': 'barcode', 
# #                                                                     })

# print(df_info.shape)
# df_info.to_csv('/cndd/fangming/for_hanqing/mc_mop_clusters.tsv', sep='\t', na_rep='NA', header=True, index=False)

# %% [markdown]
# # organize it

# %%
output_summary_results2 = os.path.join(outdir, 'intg_summary-{}-4-round-clustering.tsv'.format(name))
df_info2 = pd.read_csv(output_summary_results2, sep='\t')
print(df_info2.shape)
df_info2.head()
# Out:
# (408885, 19)
# /cndd/fangming/venvs/conda_dobro/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    sample  cluster_joint_r0.1  cluster_joint_r1  \
# 0     snmcseq_gene_2C_M_0                   1                11
# 1     snmcseq_gene_2C_M_1                   4                 1
# 2   snmcseq_gene_2C_M_100                   4                 1
# 3  snmcseq_gene_2C_M_1000                   4                 1
# 4  snmcseq_gene_2C_M_1001                   4                 1
#
#    cluster_joint_r2  cluster_joint_r4  tsne_x_joint  tsne_y_joint  \
# 0                10                23      0.471629     -3.134735
# 1                 8                 4     -2.414973    -12.098081
# 2                 8                49     -1.446751    -12.051894
# ...

# %%
df_info_new = (df_info2.drop(columns=['cluster_joint_r0.1', 'cluster_joint_r1', 'cluster_joint_r2', 'cluster_joint_r4'])
                       .rename(columns={
                               'tsne_x_joint': 'joint_embedding_x', 
                                'tsne_y_joint': 'joint_embedding_y', 
                                'cluster': 'single_modality_cluster',
                                'annot': 'single_modality_annot',
                                'cluster_round_2': 'joint_cluster_round2', 
                                'cluster_round_2_anno': 'joint_cluster_round2_annot', 
                                'cluster_round_3': 'joint_cluster_round3', 
                                'cluster_round_3_anno': 'joint_cluster_round3_annot', 
                                'cluster_round_3_color': 'joint_cluster_round3_color', 
                                'cluster_round_4': 'joint_cluster_round4', 
                                'cluster_round_4_anno': 'joint_cluster_round4_annot', 
                                'cluster_round_4_color': 'joint_cluster_round4_color', 
                               })
              )
            
print(df_info_new.shape)
df_info_new.head()
# Out:
# (408885, 15)
#                    sample  joint_embedding_x  joint_embedding_y      modality  \
# 0     snmcseq_gene_2C_M_0           0.471629          -3.134735  snmcseq_gene
# 1     snmcseq_gene_2C_M_1          -2.414973         -12.098081  snmcseq_gene
# 2   snmcseq_gene_2C_M_100          -1.446751         -12.051894  snmcseq_gene
# 3  snmcseq_gene_2C_M_1000          -1.901734         -13.660591  snmcseq_gene
# 4  snmcseq_gene_2C_M_1001          -0.981086         -11.936621  snmcseq_gene
#
#      modality_name single_modality_cluster  single_modality_annot  \
# 0  DNA methylation   L4-IT-Rorb_Rorb-Tenm2  L4-IT-Rorb_Rorb-Tenm2
# 1  DNA methylation             L23-IT-Cux2            L23-IT-Cux2
# 2  DNA methylation             L23-IT-Cux2            L23-IT-Cux2
# 3  DNA methylation             L23-IT-Cux2            L23-IT-Cux2
# 4  DNA methylation             L23-IT-Cux2            L23-IT-Cux2
#
#   joint_cluster_round2 joint_cluster_round2_annot joint_cluster_round3  \
# ...

# %%
# output = '/cndd/fangming/CEMBA/data/MOp_all/results_final/miniatlas_joint_clusterings.tsv'
# df_info_new.to_csv(output, sep='\t', header=True, index=False)

# %%
df_info_new.groupby('modality').size()
# Out:
# modality
# 10x_cells_v2             121440
# 10x_cells_v3              69727
# 10x_nuclei_v3             39706
# 10x_nuclei_v3_macosko    101647
# smarter_cells              6244
# smarter_nuclei             5911
# snatac_gene               54844
# snmcseq_gene               9366
# dtype: int64
